# %%
import ROOT as r

# %%
# f_coffea=r.TFile("coffea.root","RO")
# h_coffea=f_coffea.Get("all")
f_el = r.TFile("event_loop_arrays_output_hist.root", "RO")
h_el = f_el.Get("baseline_pt_total")
f_frames = r.TFile("example_FS.root", "RO")
h_frames = f_frames.Get("NOSYS/ph_pt_Muon")
c_weighted = r.TCanvas("c_weighted", "c_weighted", 800, 600)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_weighted

# %%
c_weighted.Draw()
c_weighted.SetLogy()
h_el.SetLineColor(r.kRed)
# Out:
# <div id="root_plot_1756502303957" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1756502303957(Core) {
# ...

# %%
c_weighted.Draw()
c_weighted.SetLogy()
h_frames.SetLineColor(r.kRed)
# h_el.SetLineColor(r.kRed)
h_frames.Draw()
# h_el.Draw()
h_frames.GetYaxis().SetRangeUser(100, 1e5)
# h_el.GetYaxis().SetRangeUser(100,1e6)
# h_coffea.Draw("same")
h_el.Draw("same")
# Out:
# <div id="root_plot_1756502317940" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1756502317940(Core) {
# ...

# %%
print(h_frames.GetEntries())
print(h_el.GetEntries())

print(h_frames.GetSumOfWeights())
print(h_el.GetSumOfWeights())
# Out:
# 18304905.0
# 14001607.0
# 355190.46341860114
# 355190.4539922695

# %%
# h_frames.Scale(h_frames.GetEntries()/h_frames.GetSumOfWeights())
h_frames.Scale(1000.0)

# %%
c_unweighted = r.TCanvas("c_unweighted", "c_unweighted", 800, 600)
c_unweighted.SetLogy(1)

c_unweighted.Draw()
# h_frames.Draw()
h_el.Draw()
h_coffea.Draw("same")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5 #h_frames.Draw()
#       6 h_el.Draw()
# ----> 7 h_coffea.Draw("same")
#
# NameError: name 'h_coffea' is not defined
# <div id="root_plot_1756488569651" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1756488569651(Core) {
# ...

# %%
c_check = r.TCanvas("c_check", "c_check", 800, 600)

c_check.Draw()
h_check = h_frames.Clone()
h_check.Add(-1 * h_coffea)
h_check.Draw()
